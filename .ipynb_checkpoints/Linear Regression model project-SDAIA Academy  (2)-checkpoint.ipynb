# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression, LassoCV, RidgeCV 
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import train_test_split

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
df_1 = pd.read_csv('Fifa_22_players_ratings.csv')
df_2 = pd.read_csv('Fifa_22_players_ratings_1.csv')
df_3 = pd.read_csv('Fifa_22_players_ratings_2.csv')
df_4 = pd.read_csv('Fifa_22_players_ratings_3.csv')
df_5 = pd.read_csv('Fifa_22_players_ratings_4.csv')
df_6 = pd.read_csv('Fifa_22_players_ratings_5.csv')
df_7 = pd.read_csv('Fifa_22_players_ratings_6.csv')
df_both = [df_1,df_2,df_3,df_4,df_5,df_6,df_7]
df = pd.concat(df_both)

# %%
# to display all columns names
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#       Unnamed: 0                Name  Overall-Rating  Height Weight  \
# 0              0        Lionel Messi              93  170 cm  72 kg
# 1              1  Robert Lewandowski              92  185 cm  81 kg
# 2              2       Kylian Mbappé              91  182 cm  73 kg
# 3              3           Jan Oblak              91  188 cm  87 kg
# 4              4     Kevin De Bruyne              91  181 cm  70 kg
# ...          ...                 ...             ...     ...    ...
# 2995        2995        Heo Ja Woong              52  184 cm  80 kg
# 2996        2996       Theodore Rask              52  189 cm  84 kg
# 2997        2997       Karabo Molefe              52  190 cm  73 kg
# 2998        2998       Parag Shrivas              52  180 cm  73 kg
# 2999        2999      Abdallah Basit              52  180 cm  78 kg
#
#      Preferred Foot     Birth Date  Age Preferred Positions Player Work Rate  \
# 0              Left  June 24, 1987   34              RWSTCF     Medium / Low
# 1             Right  Aug. 21, 1988   33                  ST    High / Medium
# 2             Right  Dec. 20, 1998   22                STLW       High / Low
# 3             Right   Jan. 7, 1993   28                  GK  Medium / Medium
# 4             Right  June 28, 1991   30               CMCAM      High / High
# ...             ...            ...  ...                 ...              ...
# 2995          Right   May 12, 1998   23                  GK  Medium / Medium
# 2996          Right    May 1, 2000   21                  CB  Medium / Medium
# 2997          Right   Jan. 6, 2003   18                  GK  Medium / Medium
# 2998           Left   June 9, 1997   24              LBLMRB    High / Medium
# 2999          Right  Oct. 15, 1999   22               CMCDM  Medium / Medium
#
#              Value      Wage  Ball Control  Dribbling  Marking  Slide Tackle  \
# 0      €78.000.000  €320.000            96         96       20            24
# 1     €119.500.000  €270.000            88         85       35            19
# 2     €194.000.000  €225.000            91         93       26            32
# 3     €112.000.000  €130.000            30         12       27            18
# 4     €125.500.000  €350.000            91         88       68            53
# ...            ...       ...           ...        ...      ...           ...
# 2995      €150.000    €1.500            19         12        9            13
# 2996      €180.000    €1.500            40         33       52            51
# 2997      €180.000    €1.500            14          9        6            15
# 2998      €150.000    €1.500            31         52       46            56
# 2999      €180.000    €1.800            48         43       37            47
#
#       Stand Tackle  Aggression  Reactions  Att. Position  Interceptions  \
# 0               35          44         94             93             40
# 1               42          81         93             95             49
# 2               34          62         93             92             38
# 3               12          34         88             11             19
# 4               65          76         91             88             66
# ...            ...         ...        ...            ...            ...
# 2995            12          23         40              8              8
# 2996            53          48         44             20             50
# 2997            16          19         48              5             15
# 2998            53          52         47             46             45
# 2999            50          57         56             54             45
#
#       Vision  Composure  Crossing  Short Pass  Long Pass  Acceleration  \
# 0         95         96        85          91         91            91
# 1         81         88        71          85         70            77
# 2         82         88        78          85         71            97
# 3         65         68        13          43         40            43
# 4         94         89        94          94         93            76
# ...      ...        ...       ...         ...        ...           ...
# 2995      25         23        14          30         28            18
# 2996      32         40        25          43         44            60
# 2997      22         27         9          27         19            42
# 2998      37         37        51          43         25            64
# 2999      42         38        43          62         64            62
#
#       Stamina  Strength  Balance  Sprint Speed  Agility  Jumping  Heading  \
# 0          72        69       95            80       91       68       70
# 1          76        86       82            79       77       85       90
# 2          88        77       83            97       92       78       72
# 3          41        78       49            60       67       78       15
# 4          89        74       78            76       79       63       55
# ...       ...       ...      ...           ...      ...      ...      ...
# 2995       20        43       40            20       25       55       15
# 2996       53        64       58            55       53       67       48
# 2997       23        70       39            37       28       48       14
# 2998       62        67       65            64       53       56       35
# 2999       55        60       63            67       52       55       44
#
#       Shot Power  Finishing  Long Shots  Curve  FK Acc.  Penalties  Volleys  \
# 0             86         95          94     93       94         75       88
# 1             90         95          87     79       85         90       89
# 2             86         93          82     80       69         79       83
# 3             59         11          12     13       14         11       13
# 4             91         82          91     85       83         83       82
# ...          ...        ...         ...    ...      ...        ...      ...
# 2995          41          8           8     15       11         11        8
# 2996          41         28          32     23       27         28       25
# 2997          35          8           9     12       15         16        7
# 2998          29         27          24     34       29         39       24
# 2999          58         32          45     37       29         40       42
#
#       GK Positioning  GK Diving  GK Handling  GK Kicking  GK Reflexes
# 0                 14          6           11          15            8
# 1                  8         15            6          12           10
# 2                 11         13            5           7            6
# 3                 90         87           92          78           90
# 4                 10         15           13           5           13
# ...              ...        ...          ...         ...          ...
# 2995              52         53           53          54           52
# 2996               8          6           12          12           11
# 2997              38         58           48          46           61
# 2998               8         14            7           6           14
# 2999              13          8            6           6           11
#
# [18000 rows x 46 columns]

# %%
# drop unnamed column because we dont need it
df.drop('Unnamed: 0',axis=1, inplace=True)

# %%
db = df[df['Name'].duplicated()]
mask = (df['Name'] == 'Dele Alli')
df[mask]
# Out:
#           Name  Overall-Rating  Height Weight Preferred Foot      Birth Date  \
# 419  Dele Alli              80  188 cm  80 kg          Right  April 11, 1996
# 422  Dele Alli              80  188 cm  80 kg          Right  April 11, 1996
#
#      Age Preferred Positions Player Work Rate        Value     Wage  \
# 419   25             CAMCMST    High / Medium  €26.500.000  €90.000
# 422   25             CAMCMST    High / Medium  €26.500.000  €90.000
#
#      Ball Control  Dribbling  Marking  Slide Tackle  Stand Tackle  Aggression  \
# 419            84         83       64            62            65          70
# 422            84         83       64            62            65          70
#
#      Reactions  Att. Position  Interceptions  Vision  Composure  Crossing  \
# 419         80             82             62      82         85        72
# 422         80             82             62      82         85        72
#
#      Short Pass  Long Pass  Acceleration  Stamina  Strength  Balance  \
# 419          82         80            67       82        75       68
# 422          82         80            67       82        75       68
#
#      Sprint Speed  Agility  Jumping  Heading  Shot Power  Finishing  \
# 419            68       76       71       79          78         80
# 422            68       76       71       79          78         80
#
#      Long Shots  Curve  FK Acc.  Penalties  Volleys  GK Positioning  \
# 419          74     77       60         80       79              11
# 422          74     77       60         80       79              11
#
#      GK Diving  GK Handling  GK Kicking  GK Reflexes
# 419          7            6           9            8
# 422          7            6           9            8

# %%
db.count()
# Out:
# Name                   1208
# Overall-Rating         1208
# Height                 1208
# Weight                 1208
# Preferred Foot         1208
# Birth Date             1208
# Age                    1208
# Preferred Positions    1208
# Player Work Rate       1208
# Value                  1208
# Wage                   1208
# Ball Control           1208
# Dribbling              1208
# Marking                1208
# Slide Tackle           1208
# Stand Tackle           1208
# Aggression             1208
# Reactions              1208
# Att. Position          1208
# Interceptions          1208
# Vision                 1208
# Composure              1208
# Crossing               1208
# Short Pass             1208
# Long Pass              1208
# Acceleration           1208
# Stamina                1208
# Strength               1208
# Balance                1208
# Sprint Speed           1208
# Agility                1208
# Jumping                1208
# Heading                1208
# Shot Power             1208
# Finishing              1208
# Long Shots             1208
# Curve                  1208
# FK Acc.                1208
# Penalties              1208
# Volleys                1208
# GK Positioning         1208
# GK Diving              1208
# GK Handling            1208
# GK Kicking             1208
# GK Reflexes            1208
# dtype: int64

# %%
df_droped = df
df_droped.drop_duplicates(inplace=True)

# %%
# making sure there are no duplactes
db = df_droped[df_droped['Name'].duplicated()]
m = (df_droped['Name'] == 'Emerson')
df_droped[m]
# Out:
#         Name  Overall-Rating  Height Weight Preferred Foot     Birth Date  \
# 487  Emerson              79  181 cm  79 kg          Right  Jan. 14, 1999
# 738  Emerson              78  176 cm  79 kg           Left   Aug. 3, 1994
#
#      Age Preferred Positions Player Work Rate        Value     Wage  \
# 487   22                  RB    High / Medium  €25.000.000  €70.000
# 738   27               LBLWB    High / Medium  €15.000.000  €85.000
#
#      Ball Control  Dribbling  Marking  Slide Tackle  Stand Tackle  Aggression  \
# 487            77         74       70            79            78          80
# 738            80         79       77            76            77          69
#
#      Reactions  Att. Position  Interceptions  Vision  Composure  Crossing  \
# 487         75             73             72      65         65        77
# 738         75             72             78      57         72        78
#
#      Short Pass  Long Pass  Acceleration  Stamina  Strength  Balance  \
# 487          77         65            77       82        74       67
# 738          77         66            83       70        57       76
#
#      Sprint Speed  Agility  Jumping  Heading  Shot Power  Finishing  \
# 487            85       74       79       70          77         57
# 738            78       75       67       60          80         51
#
#      Long Shots  Curve  FK Acc.  Penalties  Volleys  GK Positioning  \
# 487          62     73       47         48       44              10
# 738          77     53       71         55       51               7
#
#      GK Diving  GK Handling  GK Kicking  GK Reflexes
# 487         11           13           9           13
# 738          8           15           8           14

# %%
df_droped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2931 entries, 0 to 1499
# Data columns (total 45 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 2931 non-null   object
#  1   Overall-Rating       2931 non-null   int64
#  2   Height               2931 non-null   object
#  3   Weight               2931 non-null   object
#  4   Preferred Foot       2931 non-null   object
#  5   Birth Date           2931 non-null   object
#  6   Age                  2931 non-null   int64
#  7   Preferred Positions  2931 non-null   object
#  8   Player Work Rate     2931 non-null   object
#  9   Value                2917 non-null   object
#  10  Wage                 2917 non-null   object
#  11  Ball Control         2931 non-null   int64
#  12  Dribbling            2931 non-null   int64
#  13  Marking              2931 non-null   int64
#  14  Slide Tackle         2931 non-null   int64
#  15  Stand Tackle         2931 non-null   int64
#  16  Aggression           2931 non-null   int64
#  17  Reactions            2931 non-null   int64
#  18  Att. Position        2931 non-null   int64
#  19  Interceptions        2931 non-null   int64
#  20  Vision               2931 non-null   int64
#  21  Composure            2931 non-null   int64
#  22  Crossing             2931 non-null   int64
#  23  Short Pass           2931 non-null   int64
#  24  Long Pass            2931 non-null   int64
#  25  Acceleration         2931 non-null   int64
#  26  Stamina              2931 non-null   int64
#  27  Strength             2931 non-null   int64
#  28  Balance              2931 non-null   int64
#  29  Sprint Speed         2931 non-null   int64
#  30  Agility              2931 non-null   int64
#  31  Jumping              2931 non-null   int64
#  32  Heading              2931 non-null   int64
#  33  Shot Power           2931 non-null   int64
#  34  Finishing            2931 non-null   int64
#  35  Long Shots           2931 non-null   int64
#  36  Curve                2931 non-null   int64
#  37  FK Acc.              2931 non-null   int64
#  38  Penalties            2931 non-null   int64
#  39  Volleys              2931 non-null   int64
#  40  GK Positioning       2931 non-null   int64
#  41  GK Diving            2931 non-null   int64
#  42  GK Handling          2931 non-null   int64
#  43  GK Kicking           2931 non-null   int64
#  44  GK Reflexes          2931 non-null   int64
# dtypes: int64(36), object(9)
# memory usage: 1.0+ MB

# %%
df_droped.columns
# Out:
# Index(['Name', 'Overall-Rating', 'Height', 'Weight', 'Preferred Foot',
#        'Birth Date', 'Age', 'Preferred Positions', 'Player Work Rate', 'Value',
#        'Wage', 'Ball Control', 'Dribbling', 'Marking', 'Slide Tackle',
#        'Stand Tackle', 'Aggression', 'Reactions', 'Att. Position',
#        'Interceptions', 'Vision', 'Composure', 'Crossing', 'Short Pass',
#        'Long Pass', 'Acceleration', 'Stamina', 'Strength', 'Balance',
#        'Sprint Speed', 'Agility', 'Jumping', 'Heading', 'Shot Power',
#        'Finishing', 'Long Shots', 'Curve', 'FK Acc.', 'Penalties', 'Volleys',
#        'GK Positioning', 'GK Diving', 'GK Handling', 'GK Kicking',
#        'GK Reflexes'],
#       dtype='object')

# %%
# change preferd foot to (int) 0 for right 1 for left
replace_foot= {0:'Right', 1:'Left'}
print(replace_foot)

df_droped['Preferred Foot'] = df_droped['Preferred Foot'].str.strip()

dd = df_droped

dd['Preferred Foot'].replace(['Right','Left'],[0,1],inplace=True)
# Out:
# {0: 'Right', 1: 'Left'}

# %%
dd['Wage'].describe()
# there are players that doesnt have wage do we drop them ?
# Out:
# count        2917
# unique        162
# top       €14.500
# freq           71
# Name: Wage, dtype: object

# %%
# change wage, value,to float and height, weight to int
dd2 = dd

dd2['Wage'] = dd2['Wage'].str.strip()
dd2['Value'] = dd2['Value'].str.strip()
dd2['Height'] = dd2['Height'].str.strip()
dd2['Weight'] = dd2['Weight'].str.strip()

dd2['Wage'] = dd2['Wage'].replace('[€\.]', '', regex=True).astype(float)
dd2['Value'] = dd2['Value'].replace('[€\.]', '', regex=True).astype(float)
dd2['Height'] = dd2['Height'].replace('[cm]', '', regex=True).astype(int)
dd2['Weight'] = dd2['Weight'].replace('[kg]', '', regex=True).astype(int)

# re-naming column names as aproprate

df.rename(columns={"Height": "Height in cm", "Weight": "Weight in kg", "Value": "Value in €", "Wage": "Wage in €"})
# Out:
#                     Name  Overall-Rating  Height in cm  Weight in kg  \
# 0           Lionel Messi              93           170            72
# 1     Robert Lewandowski              92           185            81
# 2          Kylian Mbappé              91           182            73
# 3              Jan Oblak              91           188            87
# 4        Kevin De Bruyne              91           181            70
# ...                  ...             ...           ...           ...
# 1495           Sven Kums              73           176            73
# 1496     Mariano Andújar              73           194            86
# 1497        Manolo Reina              73           186            81
# 1498     Jonatan Maidana              73           185            86
# 1499          Hugo Ayala              73           183            81
#
#       Preferred Foot      Birth Date  Age Preferred Positions  \
# 0                  1   June 24, 1987   34              RWSTCF
# 1                  0   Aug. 21, 1988   33                  ST
# 2                  0   Dec. 20, 1998   22                STLW
# 3                  0    Jan. 7, 1993   28                  GK
# 4                  0   June 28, 1991   30               CMCAM
# ...              ...             ...  ...                 ...
# 1495               0   Feb. 26, 1988   33            CMCDMCAM
# 1496               0   July 30, 1983   38                  GK
# 1497               0   April 1, 1985   36                  GK
# 1498               0   July 29, 1985   36                  CB
# 1499               0  March 31, 1987   34                  CB
#
#      Player Work Rate   Value in €  Wage in €  Ball Control  Dribbling  \
# 0        Medium / Low   78000000.0   320000.0            96         96
# 1       High / Medium  119500000.0   270000.0            88         85
# 2          High / Low  194000000.0   225000.0            91         93
# 3     Medium / Medium  112000000.0   130000.0            30         12
# 4         High / High  125500000.0   350000.0            91         88
# ...               ...          ...        ...           ...        ...
# 1495    Medium / High    1900000.0    18000.0            76         70
# 1496  Medium / Medium      80000.0     5400.0            20         16
# 1497  Medium / Medium      80000.0     9600.0            18         12
# 1498       Low / High     800000.0     9000.0            62         40
# 1499    Medium / High    1000000.0    31000.0            69         51
#
#       Marking  Slide Tackle  Stand Tackle  Aggression  Reactions  \
# 0          20            24            35          44         94
# 1          35            19            42          81         93
# 2          26            32            34          62         93
# 3          27            18            12          34         88
# 4          68            53            65          76         91
# ...       ...           ...           ...         ...        ...
# 1495       74            62            67          69         70
# 1496       21            19            18          39         69
# 1497       17            12            11          35         72
# 1498       74            70            72          85         66
# 1499       72            75            75          67         74
#
#       Att. Position  Interceptions  Vision  Composure  Crossing  Short Pass  \
# 0                93             40      95         96        85          91
# 1                95             49      81         88        71          85
# 2                92             38      82         88        78          85
# 3                11             19      65         68        13          43
# 4                88             66      94         89        94          94
# ...             ...            ...     ...        ...       ...         ...
# 1495             66             75      73         81        75          77
# 1496             13             20      45         60        14          23
# 1497              9             23      31         50         8          30
# 1498             50             67      55         72        56          70
# 1499             42             73      55         78        60          74
#
#       Long Pass  Acceleration  Stamina  Strength  Balance  Sprint Speed  \
# 0            91            91       72        69       95            80
# 1            70            77       76        86       82            79
# 2            71            97       88        77       83            97
# 3            40            43       41        78       49            60
# 4            93            76       89        74       78            76
# ...         ...           ...      ...       ...      ...           ...
# 1495         76            55       72        63       73            49
# 1496         23            45       38        70       40            45
# 1497         36            54       44        65       58            59
# 1498         69            29       43        86       45            36
# 1499         69            52       67        76       36            55
#
#       Agility  Jumping  Heading  Shot Power  Finishing  Long Shots  Curve  \
# 0          91       68       70          86         95          94     93
# 1          77       85       90          90         95          87     79
# 2          92       78       72          86         93          82     80
# 3          67       78       15          59         11          12     13
# 4          79       63       55          91         82          91     85
# ...       ...      ...      ...         ...        ...         ...    ...
# 1495       68       60       62          73         66          71     76
# 1496       40       70       10          47         11          10     13
# 1497       57       66       12          50         10          20     20
# 1498       54       81       73          45         32          32     45
# 1499       59       73       74          62         44          44     51
#
#       FK Acc.  Penalties  Volleys  GK Positioning  GK Diving  GK Handling  \
# 0          94         75       88              14          6           11
# 1          85         90       89               8         15            6
# 2          69         79       83              11         13            5
# 3          14         11       13              90         87           92
# 4          83         83       82              10         15           13
# ...       ...        ...      ...             ...        ...          ...
# 1495       79         71       67              14         10           14
# 1496       16         23       11              75         72           71
# 1497       12         24       13              74         71           69
# 1498       44         46       42              14         12            9
# 1499       40         54       41              12         10           15
#
#       GK Kicking  GK Reflexes
# 0             15            8
# 1             12           10
# 2              7            6
# 3             78           90
# 4              5           13
# ...          ...          ...
# 1495          15            7
# 1496          62           75
# 1497          67           75
# 1498          14           14
# 1499          17           11
#
# [2931 rows x 45 columns]

# %%
# droping 14 rows becaus ethere are no value nor age 
# dd2.isna().sum() to check

# %%
ddd = dd2
ddd.dropna(inplace=True)

# %%
# modling

# %%
lr = LinearRegression()

# %%
x = ddd[['Height', 'Weight', 'Preferred Foot', 'Age', 'Value',
       'Wage', 'Ball Control', 'Dribbling', 'Marking', 'Slide Tackle',
       'Stand Tackle', 'Aggression', 'Reactions', 'Att. Position',
       'Interceptions', 'Vision', 'Composure', 'Crossing', 'Short Pass',
       'Long Pass', 'Acceleration', 'Stamina', 'Strength', 'Balance',
       'Sprint Speed', 'Agility', 'Jumping', 'Heading', 'Shot Power',
       'Finishing', 'Long Shots', 'Curve', 'FK Acc.', 'Penalties', 'Volleys',
       'GK Positioning', 'GK Diving', 'GK Handling', 'GK Kicking',
       'GK Reflexes']]
y = ddd['Overall-Rating']

# %%
lr.fit(x,y)
# Out:
# LinearRegression()

# %%
y_predict = lr.predict(x)
y_predict
# Out:
# array([ 92.1231382 ,  95.34153645, 102.13670191, ...,  75.52138031,
#         72.95176621,  76.10364679])

# %%
print(lr.coef_)
print(lr.intercept_)
# Out:
# [-1.44590400e-03  5.19220858e-03  4.20213298e-02  1.31385152e-01
#   1.09045946e-07  9.26562157e-06  3.87903820e-02  1.58805020e-02
#   9.37793870e-03  1.07937821e-02 -8.32733299e-03  2.04344692e-03
#   1.69831299e-01 -2.83242907e-02 -3.78199843e-03 -7.29365138e-03
#   2.81765989e-02  6.36140999e-03  5.34406968e-02 -2.14938644e-03
#   1.68113170e-02  9.96016768e-04  2.95348323e-03 -1.62687234e-03
#   1.37022316e-02 -6.87988172e-03 -4.53052724e-03  1.72479348e-02
#   2.07069502e-02  8.76089667e-03 -1.36239128e-02 -1.46547193e-03
#   2.54509888e-03 -4.26630053e-03 -2.23192036e-04  2.61162460e-02
#   3.57618582e-02  2.40444755e-02 -1.04046910e-02  2.78685428e-02]
# 45.09543814337242

# %%
mse1 = mean_squared_error(y, y_predict, squared=True)
rmse1 = mean_squared_error(y, y_predict, squared=False)
mae1 = mean_absolute_error(y, y_predict)
r2 = r2_score(y, y_predict)

# %%
print('Mean Square Error = ', mse1)
print ('Mean Absoluter Error=', mae1)
print ('Root Mean Square Error =', rmse1)
print ('R^2 =', r2)
print ('r =', r2**0.5)
# Out:
# Mean Square Error =  1.620148086930308
# Mean Absoluter Error= 0.9622448377802411
# Root Mean Square Error = 1.2728503788467473
# R^2 = 0.8554029452075642
# r = 0.9248799625938299

# %%
X, X_test, y, y_test = train_test_split(ddd[['Height', 'Weight', 'Preferred Foot', 'Age', 'Value',
       'Wage', 'Ball Control', 'Dribbling', 'Marking', 'Slide Tackle',
       'Stand Tackle', 'Aggression', 'Reactions', 'Att. Position',
       'Interceptions', 'Vision', 'Composure', 'Crossing', 'Short Pass',
       'Long Pass', 'Acceleration', 'Stamina', 'Strength', 'Balance',
       'Sprint Speed', 'Agility', 'Jumping', 'Heading', 'Shot Power',
       'Finishing', 'Long Shots', 'Curve', 'FK Acc.', 'Penalties', 'Volleys',
       'GK Positioning', 'GK Diving', 'GK Handling', 'GK Kicking',
       'GK Reflexes']], 
                                        ddd['Overall-Rating'], test_size=0.2, random_state=40)

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.25, random_state=40)

# %%
lr = LinearRegression()
lr.fit(X_train,y_train)
lr.score(X_train,y_train)
# Out:
# 0.8631751534313808

# %%
lr.score(X_val,y_val)
# Out:
# 0.8483555997619034

# %%
# Don't forget to standard scale your data for regularized regression
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Apply the same scaler to val set
X_val_scaled = scaler.transform(X_val)

# Fit a LASSO model using polynomial features
lasso = LassoCV()
lasso.fit(X_train_scaled,y_train)
lasso.score(X_train_scaled,y_train)
# Out:
# 0.8626436095937553

# %%
lasso.score(X_val_scaled, y_val)
# Out:
# 0.8487648487953067

# %%
# Don't forget to standard scale your data for regularized regression
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# Apply the same scaler to val set
X_val_scaled = scaler.transform(X_val)

# Fit a LASSO model using polynomial features
R = RidgeCV()
R.fit(X_train_scaled,y_train)
R.score(X_train_scaled,y_train)
# Out:
# 0.8629941684755056

# %%
R.score(X_val_scaled, y_val)
# Out:
# 0.8492047996728336

# %%
X, X_test, y, y_test = train_test_split(ddd[['Height', 'Weight', 'Preferred Foot', 'Age', 'Value',
       'Wage', 'Ball Control', 'Dribbling', 'Marking', 'Slide Tackle',
       'Stand Tackle', 'Aggression', 'Reactions', 'Att. Position',
       'Interceptions', 'Vision', 'Composure', 'Crossing', 'Short Pass',
       'Long Pass', 'Acceleration', 'Stamina', 'Strength', 'Balance',
       'Sprint Speed', 'Agility', 'Jumping', 'Heading', 'Shot Power',
       'Finishing', 'Long Shots', 'Curve', 'FK Acc.', 'Penalties', 'Volleys',
       'GK Positioning', 'GK Diving', 'GK Handling', 'GK Kicking',
       'GK Reflexes']], 
                                        ddd['Overall-Rating'], test_size=0.2, random_state=40)

# %%
lr = LinearRegression()
lr.fit(X,y)
lr.score(X,y)
# Out:
# 0.8603141906598618

# %%
lr.score(X_test,y_test)
# Out:
# 0.8298993861500275
