# %%
from bs4 import BeautifulSoup
import requests
import time, os
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as plt
# %matplotlib inline

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
#chrome Driver is the PATH to our folder containing the driver
chromedriver = "C:\Program Files (x86)\Google\Chrome\Application\chromedriver" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver

# %%
# 1- Go to "https://footystats.org/"
footy = "https://footystats.org/"
page = requests.get(footy).text

# %%
driver = webdriver.Chrome(chromedriver)
driver.get(footy)

# %%
driver.implicitly_wait(10)
driver.maximize_window()

# %%
leagues_hover = driver.find_element_by_xpath('//*[@id="toggle-comps"]')
leagues_click = driver.find_element_by_xpath('//*[@id="headerMenu"]/li[7]/div/div/div[1]/a[4]')
actions = ActionChains(driver)
actions.move_to_element(leagues_hover)
actions.click(leagues_click)
actions.perform()

# %%
actions = ActionChains(driver)
season_hover = driver.find_element_by_xpath('//*[@id="teamSummary"]/div/div[4]/div[2]')
season_click = driver.find_element_by_xpath('//*[@id="teamSummary"]/div/div[4]/div[2]/ul/li[4]/a')
actions.move_to_element(season_hover)
actions.click(season_click)
actions.perform()

# %% [markdown]
# #### Collecting one page after that take multiple pages

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')

# %%
#table xpath
#l = driver.find_elements_by_xpath ('//*[@id="league-tables-wrapper"]/div/div[1]/table')

# %%
#We create a data frame to store each season's data in a csv eventually
season = pd.DataFrame

# %%
#get table header
header = driver.find_elements_by_xpath('//*[@id="league-tables-wrapper"]/div/div[1]/table/thead/tr/th')
print(len(header))
# Out:
# 21

# %%
table_header=[]
for head in header:
    print(head.text)
    table_header.append(str(head.text))
    i+=1
    
table_header
# Out:
# Team
# MP
# W
# D
# L
# GF
# GA
# GD
# Pts
# ['',
#  '',
#  'Team',
#  'MP',
#  'W',
#  'D',
#  'L',
#  'GF',
#  'GA',
#  'GD',
#  'Pts',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
len(table_header)
# Out:
# 21

# %%
#get table rows (Gets the whole row as 1 string)
table_rows = driver.find_elements_by_xpath('//*[@id="league-tables-wrapper"]/div/div[1]/table/tbody/tr')
print(len(rows))
#l=driver.find_elements_by_xpath ("//*[@class= 'spTable']/tbody/tr[3]/td")
# Out:
# 20

# %%
team_table=[[] for i in range(21)]
for i in range(1,21):
     for j in range(1,22):
            row_cell = driver.find_element_by_xpath('//*[@id="league-tables-wrapper"]/div/div[1]/table/tbody/tr['+str(i)+']/td['+str(j)+']').text
            team_table[i].append(row_cell.strip(''))
            j+=1
        #print()
     i+=1

#for team in rows:
 #   print(team.text)
  #  table_header.append(str(team.text))
    


# EDIT
print(len(team_table)," ",len(team_table[1]))
# Out:
# 21   21

# %%
driver.close()

# %%
team_table
# Out:
# [[],
#  ['1',
#   '',
#   'Manchester City FC',
#   '38',
#   '32',
#   '4',
#   '2',
#   '106',
#   '27',
#   '+79',
#   '100',
#   'WWDWW',
#   '2.63',
#   '47%',
#   '53%',
#   '2.22',
#   '',
#   '',
#   '84%',
#   '71%',
#   '3.50'],
#  ['2',
#   '',
#   'Manchester United FC',
#   '38',
#   '25',
#   '6',
#   '7',
#   '68',
#   '28',
#   '+40',
#   '81',
#   'WWLDW',
#   '2.13',
#   '50%',
#   '37%',
#   '1.5',
#   '',
#   '',
#   '66%',
#   '50%',
#   '2.53'],
#  ['3',
#   '',
#   'Tottenham Hotspur FC',
#   '38',
#   '23',
#   '8',
#   '7',
#   '74',
#   '36',
#   '+38',
#   '77',
#   'DWLWW',
#   '2.03',
#   '42%',
#   '50%',
#   '1.83',
#   '',
#   '',
#   '79%',
#   '45%',
#   '2.89'],
#  ['4',
#   '',
#   'Liverpool FC',
#   '38',
#   '21',
#   '12',
#   '5',
#   '84',
#   '38',
#   '+46',
#   '75',
#   'WDDLW',
#   '1.97',
#   '45%',
#   '47%',
#   '2.01',
#   '',
#   '',
#   '82%',
#   '66%',
#   '3.21'],
#  ['5',
#   '',
#   'Chelsea FC',
#   '38',
#   '21',
#   '7',
# ...

# %%
df = pd.DataFrame(team_table, columns = table_header)
df.dropna()
# Out:
#                                Team  MP   W   D   L   GF  GA   GD  ...        \
# 1    1           Manchester City FC  38  32   4   2  106  27  +79  ...
# 2    2         Manchester United FC  38  25   6   7   68  28  +40  ...
# 3    3         Tottenham Hotspur FC  38  23   8   7   74  36  +38  ...
# 4    4                 Liverpool FC  38  21  12   5   84  38  +46  ...
# 5    5                   Chelsea FC  38  21   7  10   62  38  +24  ...
# 6    6                   Arsenal FC  38  19   6  13   74  51  +23  ...
# 7    7                   Burnley FC  38  14  12  12   36  39   -3  ...
# 8    8                   Everton FC  38  13  10  15   44  58  -14  ...
# 9    9            Leicester City FC  38  12  11  15   56  60   -4  ...
# 10  10          Newcastle United FC  38  12   8  18   39  47   -8  ...
# 11  11            Crystal Palace FC  38  11  11  16   45  55  -10  ...
# 12  12              AFC Bournemouth  38  11  11  16   45  61  -16  ...
# ...

# %%
df['GD'] = pd.to_numeric(df['GD'])
df['Pts'] = pd.to_numeric(df['Pts'])
df['W'] = pd.to_numeric(df['W'])
df['L'] = pd.to_numeric(df['L'])
df['D'] = pd.to_numeric(df['D'])
df.dtypes
# Out:
#          object
#          object
# Team     object
# MP       object
# W       float64
# D       float64
# L       float64
# GF       object
# GA       object
# GD      float64
# Pts     float64
#          object
#          object
#          object
#          object
#          object
#          object
#          object
#          object
#          object
#          object
# dtype: object

# %%
#open connection to footypage
#Hover and select premier league
#given the seasons wanted, iterate over them
season(url,season_xpath)
    call table xpath

# %%
sns.set_style('whitegrid')
sns.regplot(x=df["GD"], y=df["Pts"], data=df)
# Out:
# <AxesSubplot:xlabel='GD', ylabel='Pts'>

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
X_ADS = df[['GD','W','D','L']]
y_P = df['Pts']
#X_ADS
#y_P
lr.fit(X_ADS,y_P)
ypred_W=lr.predict(X_ADS)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-361-be10da79a3a1> in <module>
#       5 #X_ADS
#       6 #y_P
# ----> 7 lr.fit(X_ADS,y_P)
#       8 ypred_W=lr.predict(X_ADS)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in fit(self, X, y, sample_weight)
#     516         accept_sparse = False if self.positive else ['csr', 'csc', 'coo']
#     517
# --> 518         X, y = self._validate_data(X, y, accept_sparse=accept_sparse,
#     519                                    y_numeric=True, multi_output=True)
#     520
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     431                 y = check_array(y, **check_y_params)
#     432             else:
# --> 433                 X, y = check_X_y(X, y, **check_params)
#     434             out = X, y
#     435
#
# ...
